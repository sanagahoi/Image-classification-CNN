# %% [markdown]
# <a href="https://colab.research.google.com/github/sanagahoi/Image-classification-CNN/blob/main/image_classification_using_CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.datasets import cifar10
import matplotlib.pyplot as plt
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

# %%
X_train.shape

# %%
X_test

# %%
X_train[0]

# %%
# we can get the dataset columns name from going to the link by searching of cifar 10 dataset
classes = ['airplane', 'automobile', 'bird','cat', 'deer', 'dog','frog', 'horse', 'ship', 'truck']

# %%
y_train.shape

# %%
# 1d array of y train
y_train[:5]

# %%
y_train = y_train.reshape(-1, )  #-1 refers to no change in 50000 but blank refers to flatten the array of number
y_train[:5]

# %%
def plot_sample(X,y,index):
  plt.figure(figsize=(2,2))
  plt.imshow(X_train[index])
  plt.xlabel(classes[y_train[index]])

# %%
plot_sample(X_train,y_train,0)

# %%
plot_sample(X_train,y_train,3)

# %%
# pixel value ranges to 255 so we need to normalize it in the data by division

X_train[0]

# %%
X_train[0]/255

# %%
X_train = X_train/255
X_test = X_test/255

# %%
ANN = models.Sequential([
     layers.Flatten(input_shape=(32,32,3)),
     layers.Dense(3000, activation='relu'),
     layers.Dense(1000, activation='relu'),
     layers.Dense(10, activation='sigmoid')
 ])
ANN.compile(optimizer='SGD',
              loss = 'sparse_categorical_crossentropy',
              metrics=['accuracy']
              )
ANN.fit(X_train, y_train, epochs=10)

# %%
ANN.evaluate(X_test,y_test)

# %%
# classification report
from sklearn.metrics import confusion_matrix, classification_report

y_pred = ANN.predict(X_test)
y_pred_classes = [np.argmax(element) for element in y_pred]

print("Classification Report: \n", classification_report(y_test, y_pred_classes))

# %%
# softmax normalize the probability
# loopy pattern filter, vertical line filter, diagonal line filter

cnn = models.Sequential([
    #cnn
    layers.Conv2D(filters=32, kernel_size=(3,3), activation='relu', input_shape=(32,32,3)),
    layers.MaxPooling2D((2,2)),

    layers.Conv2D(filters=64, kernel_size=(3,3), activation='relu'),
    layers.MaxPooling2D((2,2)),

    #dense
    layers.Flatten(),
    layers.Dense(64, activation='relu'),
    layers.Dense(10, activation='softmax')
])

# %%
cnn.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
cnn.fit(X_train, y_train, epochs=10)

# %%
cnn.evaluate(x=X_test, y=y_test)

# %%
y_test = y_test.reshape(-1,)
y_test[:5]

# %%
plot_sample(X_test, y_test, 0)

# %%
plot_sample(X_test, y_test, 4)

# %%
y_pred= cnn.predict(X_test)
y_pred[:5]

# %%
np.argmax(y_pred[0])

# %%
y_classes = [np.argmax(element) for element in y_pred]
print(y_classes[:5])

# %%
plot_sample(X_test, y_test, 1)

# %%
classes[y_classes[1]]

# %%
print('classification report: \n', classification_report(y_test, y_classes))
